# %% [markdown]
# ##Flight price Prediction(EDA and Feature Enginnering)

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train_df=pd.read_excel('Data_Train.xlsx')

# %%
train_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
test_df=pd.read_excel('Test_set.xlsx')

# %%
test_df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
df=pd.concat([test_df, train_df])

# %%
df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info
#
#    Price
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %%
df['Date_of_Journey'].str.split('/').str[0] ##we get all the dates
# Out:
# 0         6
# 1        12
# 2        21
# 3        21
# 4        24
#          ..
# 10678     9
# 10679    27
# 10680    27
# 10681    01
# 10682     9
# Name: Date_of_Journey, Length: 13354, dtype: object

# %%
## Feature engineering process
df['Date']=df['Date_of_Journey'].str.split('/').str[0]
df['Month']=df['Date_of_Journey'].str.split('/').str[1]
df['Year']=df['Date_of_Journey'].str.split('/').str[2]

# %%
df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info
#
#    Price Date Month  Year
# 0    NaN    6    06  2019
# 1    NaN   12    05  2019
# 2    NaN   21    05  2019
# 3    NaN   21    05  2019
# 4    NaN   24    06  2019

# %%
df['Date']=df['Date'].astype(int)
df['Month']=df['Month'].astype(int)
df['Year']=df['Year'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Date             13354 non-null  int32
#  12  Month            13354 non-null  int32
#  13  Year             13354 non-null  int32
# dtypes: float64(1), int32(3), object(10)
# memory usage: 1.4+ MB

# %%
df.drop('Date_of_Journey',axis=1, inplace = True)

# %%
df.head()
# Out:
#              Airline    Source Destination            Route Dep_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55
#
#    Arrival_Time Duration Total_Stops              Additional_Info  Price  \
# 0  04:25 07 Jun  10h 55m      1 stop                      No info    NaN
# 1         10:20       4h      1 stop                      No info    NaN
# 2  19:00 22 May  23h 45m      1 stop  In-flight meal not included    NaN
# 3         21:00      13h      1 stop                      No info    NaN
# 4  02:45 25 Jun   2h 50m    non-stop                      No info    NaN
#
#    Date  Month  Year
# 0     6      6  2019
# 1    12      5  2019
# 2    21      5  2019
# 3    21      5  2019
# 4    24      6  2019

# %%
df['Arrival_Time']=df['Arrival_Time'].str.split(' ').str[0]

# %%
df.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# Date                  0
# Month                 0
# Year                  0
# dtype: int64

# %%
df['Arrival_hour']=df['Arrival_Time'].str.split(':').str[0]
df['Arrival_minutes']=df['Arrival_Time'].str.split(':').str[1]

# %%
df.head()
# Out:
#              Airline    Source Destination            Route Dep_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55
#
#   Arrival_Time Duration Total_Stops              Additional_Info  Price  Date  \
# 0        04:25  10h 55m      1 stop                      No info    NaN     6
# 1        10:20       4h      1 stop                      No info    NaN    12
# 2        19:00  23h 45m      1 stop  In-flight meal not included    NaN    21
# 3        21:00      13h      1 stop                      No info    NaN    21
# 4        02:45   2h 50m    non-stop                      No info    NaN    24
#
#    Month  Year Arrival_hour Arrival_minutes
# 0      6  2019           04              25
# 1      5  2019           10              20
# 2      5  2019           19              00
# 3      5  2019           21              00
# 4      6  2019           02              45

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Arrival_Time     13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Total_Stops      13353 non-null  object
#  8   Additional_Info  13354 non-null  object
#  9   Price            10683 non-null  float64
#  10  Date             13354 non-null  int32
#  11  Month            13354 non-null  int32
#  12  Year             13354 non-null  int32
#  13  Arrival_hour     13354 non-null  object
#  14  Arrival_minutes  13354 non-null  object
# dtypes: float64(1), int32(3), object(11)
# memory usage: 1.5+ MB

# %%
df['Arrival_hour']=df['Arrival_hour'].astype(int)
df['Arrival_minutes']=df['Arrival_minutes'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Arrival_Time     13354 non-null  object
#  6   Duration         13354 non-null  object
#  7   Total_Stops      13353 non-null  object
#  8   Additional_Info  13354 non-null  object
#  9   Price            10683 non-null  float64
#  10  Date             13354 non-null  int32
#  11  Month            13354 non-null  int32
#  12  Year             13354 non-null  int32
#  13  Arrival_hour     13354 non-null  int32
#  14  Arrival_minutes  13354 non-null  int32
# dtypes: float64(1), int32(5), object(9)
# memory usage: 1.4+ MB

# %%
df.drop('Arrival_Time', axis=1, inplace =True)

# %%
df.head()
# Out:
#              Airline    Source Destination            Route Dep_Time Duration  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30  10h 55m
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20       4h
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15  23h 45m
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00      13h
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55   2h 50m
#
#   Total_Stops              Additional_Info  Price  Date  Month  Year  \
# 0      1 stop                      No info    NaN     6      6  2019
# 1      1 stop                      No info    NaN    12      5  2019
# 2      1 stop  In-flight meal not included    NaN    21      5  2019
# 3      1 stop                      No info    NaN    21      5  2019
# 4    non-stop                      No info    NaN    24      6  2019
#
#    Arrival_hour  Arrival_minutes
# 0             4               25
# 1            10               20
# 2            19                0
# 3            21                0
# 4             2               45

# %%
df['Dep_hour']=df['Dep_Time'].str.split(':').str[0]
df['Dep_minutes']=df['Dep_Time'].str.split(':').str[1]

# %%
df.head()
# Out:
#              Airline    Source Destination            Route Dep_Time Duration  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30  10h 55m
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20       4h
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15  23h 45m
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00      13h
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55   2h 50m
#
#   Total_Stops              Additional_Info  Price  Date  Month  Year  \
# 0      1 stop                      No info    NaN     6      6  2019
# 1      1 stop                      No info    NaN    12      5  2019
# 2      1 stop  In-flight meal not included    NaN    21      5  2019
# 3      1 stop                      No info    NaN    21      5  2019
# 4    non-stop                      No info    NaN    24      6  2019
#
#    Arrival_hour  Arrival_minutes Dep_hour Dep_minutes
# 0             4               25       17          30
# 1            10               20       06          20
# 2            19                0       19          15
# 3            21                0       08          00
# 4             2               45       23          55

# %%
df['Dep_hour']=df['Dep_hour'].astype(int)
df['Dep_minutes']=df['Dep_minutes'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 10682
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Dep_Time         13354 non-null  object
#  5   Duration         13354 non-null  object
#  6   Total_Stops      13353 non-null  object
#  7   Additional_Info  13354 non-null  object
#  8   Price            10683 non-null  float64
#  9   Date             13354 non-null  int32
#  10  Month            13354 non-null  int32
#  11  Year             13354 non-null  int32
#  12  Arrival_hour     13354 non-null  int32
#  13  Arrival_minutes  13354 non-null  int32
#  14  Dep_hour         13354 non-null  int32
#  15  Dep_minutes      13354 non-null  int32
# dtypes: float64(1), int32(7), object(8)
# memory usage: 1.4+ MB

# %%
df['Total_Stops'].unique()
# Out:
# array(['1 stop', 'non-stop', '2 stops', '3 stops', '4 stops', nan],
#       dtype=object)

# %%
df['Total_Stops']=df['Total_Stops'].map({'non-stop': 0, '1 stop':1, '2 stops':2, '3 stops':3, '4 stops':4, 'nan':1})

# %%
df[df['Total_Stops'].isnull()]
# Out:
#         Airline Source Destination Route Dep_Time Duration  Total_Stops  \
# 9039  Air India  Delhi      Cochin   NaN    09:45  23h 40m          NaN
#
#      Additional_Info   Price  Date  Month  Year  Arrival_hour  \
# 9039         No info  7480.0     6      5  2019             9
#
#       Arrival_minutes  Dep_hour  Dep_minutes
# 9039               25         9           45

# %%
df.drop('Route', axis=1, inplace =True)

# %%
df.head()
# Out:
#              Airline    Source Destination Dep_Time Duration  Total_Stops  \
# 0        Jet Airways     Delhi      Cochin    17:30  10h 55m          1.0
# 1             IndiGo   Kolkata    Banglore    06:20       4h          1.0
# 2        Jet Airways     Delhi      Cochin    19:15  23h 45m          1.0
# 3  Multiple carriers     Delhi      Cochin    08:00      13h          1.0
# 4           Air Asia  Banglore       Delhi    23:55   2h 50m          0.0
#
#                Additional_Info  Price  Date  Month  Year  Arrival_hour  \
# 0                      No info    NaN     6      6  2019             4
# 1                      No info    NaN    12      5  2019            10
# 2  In-flight meal not included    NaN    21      5  2019            19
# 3                      No info    NaN    21      5  2019            21
# 4                      No info    NaN    24      6  2019             2
#
#    Arrival_minutes  Dep_hour  Dep_minutes
# 0               25        17           30
# 1               20         6           20
# 2                0        19           15
# 3                0         8            0
# 4               45        23           55

# %%
df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Long layover', 'Business class',
#        'Change airports', '1 Short layover', 'No Info', 'Red-eye flight',
#        '2 Long layover'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Dep_Time         13354 non-null  object
#  4   Duration         13354 non-null  object
#  5   Total_Stops      13353 non-null  float64
#  6   Additional_Info  13354 non-null  object
#  7   Price            10683 non-null  float64
#  8   Date             13354 non-null  int32
#  9   Month            13354 non-null  int32
#  10  Year             13354 non-null  int32
#  11  Arrival_hour     13354 non-null  int32
#  12  Arrival_minutes  13354 non-null  int32
#  13  Dep_hour         13354 non-null  int32
#  14  Dep_minutes      13354 non-null  int32
# dtypes: float64(2), int32(7), object(6)
# memory usage: 1.3+ MB

# %%
df['duration_hour']=df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
df[df['duration_hour']=='5m']
# Out:
#         Airline  Source Destination Dep_Time Duration  Total_Stops  \
# 2660  Air India  Mumbai   Hyderabad    16:50       5m          2.0
# 6474  Air India  Mumbai   Hyderabad    16:50       5m          2.0
#
#      Additional_Info    Price  Date  Month  Year  Arrival_hour  \
# 2660         No info      NaN    12      3  2019            16
# 6474         No info  17327.0     6      3  2019            16
#
#       Arrival_minutes  Dep_hour  Dep_minutes duration_hour
# 2660               55        16           50            5m
# 6474               55        16           50            5m

# %%
df.drop(6474, axis=0, inplace =True)
df.drop(2660, axis=0, inplace =True)

# %%
df['duration_hour']=df['duration_hour'].astype(int)

# %%
df.drop('Duration', axis=1, inplace =True)

# %%
df.head()
# Out:
#              Airline    Source Destination Dep_Time  Total_Stops  \
# 0        Jet Airways     Delhi      Cochin    17:30          1.0
# 1             IndiGo   Kolkata    Banglore    06:20          1.0
# 2        Jet Airways     Delhi      Cochin    19:15          1.0
# 3  Multiple carriers     Delhi      Cochin    08:00          1.0
# 4           Air Asia  Banglore       Delhi    23:55          0.0
#
#                Additional_Info  Price  Date  Month  Year  Arrival_hour  \
# 0                      No info    NaN     6      6  2019             4
# 1                      No info    NaN    12      5  2019            10
# 2  In-flight meal not included    NaN    21      5  2019            19
# 3                      No info    NaN    21      5  2019            21
# 4                      No info    NaN    24      6  2019             2
#
#    Arrival_minutes  Dep_hour  Dep_minutes  duration_hour
# 0               25        17           30             10
# 1               20         6           20              4
# 2                0        19           15             23
# 3                0         8            0             13
# 4               45        23           55              2

# %%
df['Airline'].unique()
# Out:
# array(['Jet Airways', 'IndiGo', 'Multiple carriers', 'Air Asia',
#        'Air India', 'Vistara', 'SpiceJet', 'Vistara Premium economy',
#        'GoAir', 'Multiple carriers Premium economy',
#        'Jet Airways Business', 'Trujet'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder 
labelencoder=LabelEncoder()

# %%
df['Airline']=labelencoder.fit_transform(df['Airline'])
df['Source']=labelencoder.fit_transform(df['Source'])
df['Destination']=labelencoder.fit_transform(df['Destination'])
df['Additional_Info']=labelencoder.fit_transform(df['Additional_Info'])

# %%
df.shape
# Out:
# (13351, 15)

# %%
df.head()
# Out:
#    Airline  Source  Destination Dep_Time  Total_Stops  Additional_Info  Price  \
# 0        4       2            1    17:30          1.0                8    NaN
# 1        3       3            0    06:20          1.0                8    NaN
# 2        4       2            1    19:15          1.0                5    NaN
# 3        6       2            1    08:00          1.0                8    NaN
# 4        0       0            2    23:55          0.0                8    NaN
#
#    Date  Month  Year  Arrival_hour  Arrival_minutes  Dep_hour  Dep_minutes  \
# 0     6      6  2019             4               25        17           30
# 1    12      5  2019            10               20         6           20
# 2    21      5  2019            19                0        19           15
# 3    21      5  2019            21                0         8            0
# 4    24      6  2019             2               45        23           55
#
#    duration_hour
# 0             10
# 1              4
# 2             23
# 3             13
# 4              2

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder()

# %%
ohe.fit_transform(np.array(df['Airline']).reshape(-1,1))
# Out:
# <13351x12 sparse matrix of type '<class 'numpy.float64'>'
# 	with 13351 stored elements in Compressed Sparse Row format>

# %%
df.head()
# Out:
#    Airline  Source  Destination Dep_Time  Total_Stops  Additional_Info  Price  \
# 0        4       2            1    17:30          1.0                8    NaN
# 1        3       3            0    06:20          1.0                8    NaN
# 2        4       2            1    19:15          1.0                5    NaN
# 3        6       2            1    08:00          1.0                8    NaN
# 4        0       0            2    23:55          0.0                8    NaN
#
#    Date  Month  Year  Arrival_hour  Arrival_minutes  Dep_hour  Dep_minutes  \
# 0     6      6  2019             4               25        17           30
# 1    12      5  2019            10               20         6           20
# 2    21      5  2019            19                0        19           15
# 3    21      5  2019            21                0         8            0
# 4    24      6  2019             2               45        23           55
#
#    duration_hour
# 0             10
# 1              4
# 2             23
# 3             13
# 4              2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13351 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13351 non-null  int32
#  1   Source           13351 non-null  int32
#  2   Destination      13351 non-null  int32
#  3   Dep_Time         13351 non-null  object
#  4   Total_Stops      13350 non-null  float64
#  5   Additional_Info  13351 non-null  int32
#  6   Price            10681 non-null  float64
#  7   Date             13351 non-null  int32
#  8   Month            13351 non-null  int32
#  9   Year             13351 non-null  int32
#  10  Arrival_hour     13351 non-null  int32
#  11  Arrival_minutes  13351 non-null  int32
#  12  Dep_hour         13351 non-null  int32
#  13  Dep_minutes      13351 non-null  int32
#  14  duration_hour    13351 non-null  int32
# dtypes: float64(2), int32(12), object(1)
# memory usage: 1.0+ MB

# %%
pd.get_dummies(df, columns=["Airline", "Source", "Destination"], drop_first=True)
# Out:
#       Dep_Time  Total_Stops  Additional_Info    Price  Date  Month  Year  \
# 0        17:30          1.0                8      NaN     6      6  2019
# 1        06:20          1.0                8      NaN    12      5  2019
# 2        19:15          1.0                5      NaN    21      5  2019
# 3        08:00          1.0                8      NaN    21      5  2019
# 4        23:55          0.0                8      NaN    24      6  2019
# ...        ...          ...              ...      ...   ...    ...   ...
# 10678    19:55          0.0                8   4107.0     9      4  2019
# 10679    20:45          0.0                8   4145.0    27      4  2019
# 10680    08:20          0.0                8   7229.0    27      4  2019
# 10681    11:30          0.0                8  12648.0     1      3  2019
# 10682    10:55          2.0                8  11753.0     9      5  2019
#
#        Arrival_hour  Arrival_minutes  Dep_hour  ...  Airline_11  Source_1  \
# 0                 4               25        17  ...       False     False
# 1                10               20         6  ...       False     False
# 2                19                0        19  ...       False     False
# 3                21                0         8  ...       False     False
# 4                 2               45        23  ...       False     False
# ...             ...              ...       ...  ...         ...       ...
# 10678            22               25        19  ...       False     False
# 10679            23               20        20  ...       False     False
# 10680            11               20         8  ...       False     False
# 10681            14               10        11  ...       False     False
# 10682            19               15        10  ...       False     False
#
#        Source_2  Source_3  Source_4  Destination_1  Destination_2  \
# 0          True     False     False           True          False
# 1         False      True     False          False          False
# 2          True     False     False           True          False
# 3          True     False     False           True          False
# 4         False     False     False          False           True
# ...         ...       ...       ...            ...            ...
# 10678     False      True     False          False          False
# 10679     False      True     False          False          False
# 10680     False     False     False          False           True
# 10681     False     False     False          False          False
# 10682      True     False     False           True          False
#
#        Destination_3  Destination_4  Destination_5
# 0              False          False          False
# 1              False          False          False
# 2              False          False          False
# 3              False          False          False
# 4              False          False          False
# ...              ...            ...            ...
# 10678          False          False          False
# 10679          False          False          False
# 10680          False          False          False
# 10681          False          False           True
# 10682          False          False          False
#
# [13351 rows x 32 columns]
